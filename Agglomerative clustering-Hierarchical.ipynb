# %%
import numpy as np
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/Wholesale customers data.csv')

# %%
df
# Out:
#      Channel  Region  Fresh   Milk  Grocery  Frozen  Detergents_Paper  \
# 0          2       3  12669   9656     7561     214              2674
# 1          2       3   7057   9810     9568    1762              3293
# 2          2       3   6353   8808     7684    2405              3516
# 3          1       3  13265   1196     4221    6404               507
# 4          2       3  22615   5410     7198    3915              1777
# ..       ...     ...    ...    ...      ...     ...               ...
# 435        1       3  29703  12051    16027   13135               182
# 436        1       3  39228   1431      764    4510                93
# 437        2       3  14531  15488    30243     437             14841
# 438        1       3  10290   1981     2232    1038               168
# 439        1       3   2787   1698     2510      65               477
#
#      Delicassen
# 0          1338
# 1          1776
# 2          7844
# 3          1788
# 4          5185
# ..          ...
# 435        2204
# 436        2346
# 437        1867
# 438        2125
# 439          52
#
# [440 rows x 8 columns]

# %%
df.shape
# Out:
# (440, 8)

# %%
df.dtypes
# Out:
# Channel             int64
# Region              int64
# Fresh               int64
# Milk                int64
# Grocery             int64
# Frozen              int64
# Detergents_Paper    int64
# Delicassen          int64
# dtype: object

# %%
df.isna().any()
# Out:
# Channel             False
# Region              False
# Fresh               False
# Milk                False
# Grocery             False
# Frozen              False
# Detergents_Paper    False
# Delicassen          False
# dtype: bool

# %%
from sklearn.preprocessing import normalize
data_scaled=normalize(df)
data_scaled=pd.DataFrame(data_scaled,columns=df.columns)

# %%
data_scaled.head()
# Out:
#     Channel    Region     Fresh      Milk   Grocery    Frozen  \
# 0  0.000112  0.000168  0.708333  0.539874  0.422741  0.011965
# 1  0.000125  0.000188  0.442198  0.614704  0.599540  0.110409
# 2  0.000125  0.000187  0.396552  0.549792  0.479632  0.150119
# 3  0.000065  0.000194  0.856837  0.077254  0.272650  0.413659
# 4  0.000079  0.000119  0.895416  0.214203  0.284997  0.155010
#
#    Detergents_Paper  Delicassen
# 0          0.149505    0.074809
# 1          0.206342    0.111286
# 2          0.219467    0.489619
# 3          0.032749    0.115494
# 4          0.070358    0.205294

# %%
data_scaled.shape
# Out:
# (440, 8)

# %%
import scipy.cluster.hierarchy as shc
import matplotlib.pyplot as plt
plt.figure(figsize=(10,10))
plt.title('Dendrogram')
dend=shc.dendrogram(shc.linkage(data_scaled,method='average'))

# %%
from sklearn.cluster import AgglomerativeClustering
cluster=AgglomerativeClustering(n_clusters=2,affinity='euclidean',linkage='complete')
y=cluster.fit_predict(data_scaled)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-e24508a42615> in <cell line: 0>()
#       1 from sklearn.cluster import AgglomerativeClustering
# ----> 2 cluster=AgglomerativeClustering(n_clusters=2,affinity='euclidean',linkage='complete')
#       3 y=cluster.fit_predict(data_scaled)
#
# TypeError: AgglomerativeClustering.__init__() got an unexpected keyword argument 'affinity'

# %%
cluster.labels_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-b0e227cafa6b> in <cell line: 0>()
# ----> 1 cluster.labels_
#
# NameError: name 'cluster' is not defined

# %%
y
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-9063a9f0e032> in <cell line: 0>()
# ----> 1 y
#
# NameError: name 'y' is not defined

# %%
plt.figure(figsize=(10,10))
plt.scatter(data_scaled['Milk'],data_scaled['Grocery'],c=cluster.labels_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-a295d0196704> in <cell line: 0>()
#       1 plt.figure(figsize=(10,10))
# ----> 2 plt.scatter(data_scaled['Milk'],data_scaled['Grocery'],c=cluster.labels_)
#
# NameError: name 'cluster' is not defined
